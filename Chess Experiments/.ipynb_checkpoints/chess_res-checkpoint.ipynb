# %%
import pandas as pd

# %%
df = pd.read_csv('H2H1D3.csv').drop(columns=['Unnamed: 0'])
df
# Out:
#     PLAYER         TIME  # MOVES  # EXPLORED                          OUTCOME  \
# 0        0  3703.170206       49     7330843            Termination.CHECKMATE
# 1        1  3351.212446       49     7091687            Termination.CHECKMATE
# 2        0   259.056731        8      726584            Termination.CHECKMATE
# 3        1   189.914972        7      616284            Termination.CHECKMATE
# 4        0  3927.503025       51     8453236            Termination.CHECKMATE
# 5        1  2241.381880       50     5220322            Termination.CHECKMATE
# 6        0  1028.848466       35     2589752  Termination.FIVEFOLD_REPETITION
# 7        1   666.827466       35     1879750  Termination.FIVEFOLD_REPETITION
# 8        0  4828.537593       56     9957282            Termination.CHECKMATE
# 9        1  3019.255309       55     6815579            Termination.CHECKMATE
# 10       0  3604.208399      127     7104019            Termination.CHECKMATE
# 11       1  3009.905871      126     6550924            Termination.CHECKMATE
# 12       0  1295.603964       30     3120336            Termination.CHECKMATE
# 13       1   945.240628       30     2578532            Termination.CHECKMATE
# 14       0  1751.477436       43     3991059            Termination.CHECKMATE
# 15       1  1291.229007       43     3235682            Termination.CHECKMATE
# 16       0  5415.053800      159     7571964            Termination.CHECKMATE
# 17       1  3878.200828      158     5365932            Termination.CHECKMATE
# 18       0  5868.323884       68    11156843            Termination.CHECKMATE
# 19       1  3641.847078       67     7691726            Termination.CHECKMATE
# 20       0    45.486181        4      141592            Termination.CHECKMATE
# 21       1    21.909232        3       73747            Termination.CHECKMATE
#
#     HAS WIN
# 0         0
# 1         1
# 2         1
# 3         0
# 4         1
# 5         0
# 6         0
# 7         0
# 8         1
# 9         0
# 10        1
# 11        0
# 12        0
# 13        1
# 14        0
# 15        1
# 16        1
# 17        0
# 18        1
# 19        0
# 20        1
# 21        0

# %%
# average time to conclude a game
game_times = pd.DataFrame(columns=['TIME PER GAME'])

for i in range(0, len(df.index)-1, 2):
    game_times.loc[i, 'TIME PER GAME'] = df.iloc[i, 1] + df.iloc[i+1, 1]
    
game_times
# Out:
#    TIME PER GAME
# 0    7054.382652
# 2     448.971703
# 4    6168.884905
# 6    1695.675932
# 8    7847.792903
# 10    6614.11427
# 12   2240.844592
# 14   3042.706443
# 16   9293.254629
# 18   9510.170963
# 20     67.395412

# %%
game_times['TIME PER GAME'].mean()
# Out:
# 4907.654036738656

# %%
game_times['TIME PER GAME'].std()
# Out:
# 3498.3836542872887

# %%
# average number of moves/game
game_moves = pd.DataFrame(columns=['MOVES PER GAME'])

for i in range(0, len(df.index)-1, 2):
    game_moves.loc[i, 'MOVES PER GAME'] = df.loc[i, '# MOVES'] + df.loc[i+1, '# MOVES']
    
game_moves
# Out:
#    MOVES PER GAME
# 0              98
# 2              15
# 4             101
# 6              70
# 8             111
# 10            253
# 12             60
# 14             86
# 16            317
# 18            135
# 20              7

# %%
game_moves['MOVES PER GAME'].mean()
# Out:
# 113.9090909090909

# %%
game_moves['MOVES PER GAME'].std()
# Out:
# 93.9632423295988

# %%
df[df['PLAYER'] == 0]
# Out:
#     PLAYER         TIME  # MOVES  # EXPLORED                          OUTCOME  \
# 0        0  3703.170206       49     7330843            Termination.CHECKMATE
# 2        0   259.056731        8      726584            Termination.CHECKMATE
# 4        0  3927.503025       51     8453236            Termination.CHECKMATE
# 6        0  1028.848466       35     2589752  Termination.FIVEFOLD_REPETITION
# 8        0  4828.537593       56     9957282            Termination.CHECKMATE
# 10       0  3604.208399      127     7104019            Termination.CHECKMATE
# 12       0  1295.603964       30     3120336            Termination.CHECKMATE
# 14       0  1751.477436       43     3991059            Termination.CHECKMATE
# 16       0  5415.053800      159     7571964            Termination.CHECKMATE
# 18       0  5868.323884       68    11156843            Termination.CHECKMATE
# 20       0    45.486181        4      141592            Termination.CHECKMATE
#
#     HAS WIN
# 0         0
# 2         1
# 4         1
# 6         0
# 8         1
# 10        1
# 12        0
# 14        0
# 16        1
# 18        1
# 20        1

# %%
# number of games won by white
df[df['PLAYER'] == 0]['HAS WIN'].sum()
# Out:
# 7

# %%
# time/moves, to have a rough estimate of the time needed to select an action, WHITE
time_for_move = pd.DataFrame(df[df['PLAYER'] == 0]['TIME']/df[df['PLAYER'] == 0]['# MOVES'], columns=['TIME-MOVE EST. (s)'])
time_for_move
# Out:
#     TIME-MOVE EST. (s)
# 0            75.574902
# 2            32.382091
# 4            77.009863
# 6            29.395670
# 8            86.223886
# 10           28.379594
# 12           43.186799
# 14           40.732033
# 16           34.056942
# 18           86.298881
# 20           11.371545

# %%
pd.DataFrame(time_for_move['TIME-MOVE EST. (s)'].describe().iloc[1:])
# Out:
#       TIME-MOVE EST. (s)
# mean           49.510201
# std            26.630382
# min            11.371545
# 25%            30.888881
# 50%            40.732033
# 75%            76.292383
# max            86.298881

# %%
# time/moves, to have a rough estimate of the time needed to select an action, WHITE
state_for_move = pd.DataFrame(df[df['PLAYER'] == 0]['# EXPLORED']/df[df['PLAYER'] == 0]['# MOVES'], columns=['STATE-MOVE EST. (s)'])
state_for_move
# Out:
#     STATE-MOVE EST. (s)
# 0         149609.040816
# 2          90823.000000
# 4         165749.725490
# 6          73992.914286
# 8         177808.607143
# 10         55937.157480
# 12        104011.200000
# 14         92815.325581
# 16         47622.415094
# 18        164071.220588
# 20         35398.000000

# %%
pd.DataFrame(state_for_move['STATE-MOVE EST. (s)'].describe().iloc[1:])
# Out:
#       STATE-MOVE EST. (s)
# mean        105258.055134
# std          51308.794965
# min          35398.000000
# 25%          64965.035883
# 50%          92815.325581
# 75%         156840.130702
# max         177808.607143

# %%
df[df['PLAYER'] == 1]
# Out:
#     PLAYER         TIME  # MOVES  # EXPLORED                          OUTCOME  \
# 1        1  3351.212446       49     7091687            Termination.CHECKMATE
# 3        1   189.914972        7      616284            Termination.CHECKMATE
# 5        1  2241.381880       50     5220322            Termination.CHECKMATE
# 7        1   666.827466       35     1879750  Termination.FIVEFOLD_REPETITION
# 9        1  3019.255309       55     6815579            Termination.CHECKMATE
# 11       1  3009.905871      126     6550924            Termination.CHECKMATE
# 13       1   945.240628       30     2578532            Termination.CHECKMATE
# 15       1  1291.229007       43     3235682            Termination.CHECKMATE
# 17       1  3878.200828      158     5365932            Termination.CHECKMATE
# 19       1  3641.847078       67     7691726            Termination.CHECKMATE
# 21       1    21.909232        3       73747            Termination.CHECKMATE
#
#     HAS WIN
# 1         1
# 3         0
# 5         0
# 7         0
# 9         0
# 11        0
# 13        1
# 15        1
# 17        0
# 19        0
# 21        0

# %%
# number of games won by black
df[df['PLAYER'] == 1]['HAS WIN'].sum()
# Out:
# 3

# %%
# time/moves, to have a rough estimate of the time needed to select an action, WHITE
time_for_move = pd.DataFrame(df[df['PLAYER'] == 1]['TIME']/df[df['PLAYER'] == 1]['# MOVES'], columns=['TIME-MOVE EST. (s)'])
time_for_move
# Out:
#     TIME-MOVE EST. (s)
# 1            68.392091
# 3            27.130710
# 5            44.827638
# 7            19.052213
# 9            54.895551
# 11           23.888142
# 13           31.508021
# 15           30.028582
# 17           24.545575
# 19           54.355927
# 21            7.303077

# %%
pd.DataFrame(time_for_move['TIME-MOVE EST. (s)'].describe().iloc[1:])
# Out:
#       TIME-MOVE EST. (s)
# mean           35.084321
# std            18.262189
# min             7.303077
# 25%            24.216858
# 50%            30.028582
# 75%            49.591782
# max            68.392091

# %%
# time/moves, to have a rough estimate of the time needed to select an action, WHITE
state_for_move = pd.DataFrame(df[df['PLAYER'] == 1]['# EXPLORED']/df[df['PLAYER'] == 1]['# MOVES'], columns=['STATE-MOVE EST. (s)'])
state_for_move
# Out:
#     STATE-MOVE EST. (s)
# 1         144728.306122
# 3          88040.571429
# 5         104406.440000
# 7          53707.142857
# 9         123919.618182
# 11         51991.460317
# 13         85951.066667
# 15         75248.418605
# 17         33961.594937
# 19        114801.880597
# 21         24582.333333

# %%
pd.DataFrame(state_for_move['STATE-MOVE EST. (s)'].describe().iloc[1:])
# Out:
#       STATE-MOVE EST. (s)
# mean         81939.893913
# std          38305.646150
# min          24582.333333
# 25%          52849.301587
# 50%          85951.066667
# 75%         109604.160299
# max         144728.306122

# %%
pd.DataFrame(df[df['PLAYER'] == 1]['# EXPLORED']/df[df['PLAYER'] == 1]['# MOVES'], columns=['STATE-MOVE EST. (s)']).describe().iloc[1:].iloc[0].iloc[0]
# Out:
# 81939.89391325606

# %%
pd.DataFrame(df[df['PLAYER'] == 0]['# EXPLORED']/df[df['PLAYER'] == 0]['# MOVES'], columns=['STATE-MOVE EST. (s)']).describe().iloc[1:].iloc[0].iloc[0]
# Out:
# 105258.05513448903

# %%
pd.DataFrame(df[df['PLAYER'] == 0]['# EXPLORED']).describe().iloc[1:, ]
# Out:
#         # EXPLORED
# mean  5.649410e+06
# std   3.721135e+06
# min   1.415920e+05
# 25%   2.855044e+06
# 50%   7.104019e+06
# 75%   8.012600e+06
# max   1.115684e+07

# %%
pd.DataFrame(df[df['PLAYER'] == 1]['# EXPLORED']).describe().iloc[1:,]
# Out:
#         # EXPLORED
# mean  4.283651e+06
# std   2.721345e+06
# min   7.374700e+04
# 25%   2.229141e+06
# 50%   5.220322e+06
# 75%   6.683252e+06
# max   7.691726e+06

# %%
# effective branching factor
from scipy.optimize import root_scalar

# Define the function to find the root of
def equation(x, N):
    return x + x**2 + x**3 - N

# Number of nodes explored and depth of search
D = 3     # Depth of search

# Solve the equation to find the branching factor x
N = pd.DataFrame(df[df['PLAYER'] == 0]['# EXPLORED']/df[df['PLAYER'] == 0]['# MOVES'], columns=['STATE-MOVE EST. (s)']).describe().iloc[1:].iloc[0].iloc[0]

result1 = root_scalar(equation, args=(N,), bracket=[0, N])  # Provide a bracket for the solution

N = pd.DataFrame(df[df['PLAYER'] == 1]['# EXPLORED']/df[df['PLAYER'] == 1]['# MOVES'], columns=['STATE-MOVE EST. (s)']).describe().iloc[1:].iloc[0].iloc[0]
result2 = root_scalar(equation, args=(N,), bracket=[0, N])

# Check if a solution was found
if result1.converged:
    x1 = result1.root
    print(f"Estimated branching factor (x) for player 0: {x1:.2f}")
else:
    print("No solution found within the specified bracket.")


if result2.converged:
    x2 = result2.root
    print(f"Estimated branching factor (x) for player 1: {x2:.2f}")
else:
    print("No solution found within the specified bracket.")
# Out:
# Estimated branching factor (x) for player 0: 177.77
# Estimated branching factor (x) for player 1: 162.07
